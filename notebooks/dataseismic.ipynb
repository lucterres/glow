# %%
import dataSeismic2 as ds
import numpy as np

# %%
import os
from torchvision import datasets

tgsroot = "/nethome/atena_projetos/cym7/dataset/tgsSalt/test"
os.path.isdir(tgsroot)
# Out:
# True

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

im_frame = Image.open(tgsroot + '221f271d8a.png')

# %%
plt.figure(figsize=(20,20))
plt.subplot(1, 2, 1); plt.imshow(im_frame);  plt.axis('off')
plt.title('Test set')
plt.show()

# %%
trainset = ds.train_dataset
trainloader=ds.train_loader

# %%
import matplotlib.pyplot as plt
from torchvision import utils
i=2

tensorImg = trainset[i][0]
numpyImg = tensorImg.numpy()[0]
plt.figure(figsize=(20,20))
plt.subplot(1, 2, 1); plt.imshow(numpyImg);  plt.axis('off')
plt.title(trainset[i][1])
plt.show()

# %%
import os
import dir_local as d
from PIL import Image

# %%
img_dir = d.TRAIN_IMAGE_DIR
filename = '0d3b5ec2a8' 
filepath = filename + '.png'
img_path = os.path.join(img_dir, filepath)
image = Image.open(img_path)

image.getbbox()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-2698dd41d10f> in <module>
# ----> 1 img_dir = d.TRAIN_IMAGE_DIR
#       2 filename = '0d3b5ec2a8'
#       3 filepath = filename + '.png'
#       4 img_path = os.path.join(img_dir, filepath)
#       5 image = Image.open(img_path)
#
# AttributeError: module 'dir_local' has no attribute 'TRAIN_IMAGE_DIR'

# %%
numpyImg.shape
numpyImg
# Out:
# array([[0.7490196 , 0.5882353 , 0.4509804 , ..., 0.65882355, 0.654902  ,
#         0.54509807],
#        [0.85490197, 0.67058825, 0.53333336, ..., 0.7294118 , 0.6862745 ,
#         0.5764706 ],
#        [0.89411765, 0.7411765 , 0.64705884, ..., 0.7254902 , 0.6431373 ,
#         0.5764706 ],
#        ...,
#        [0.9137255 , 0.73333335, 0.68235296, ..., 0.6627451 , 0.6784314 ,
#         0.54509807],
#        [0.9372549 , 0.78039217, 0.7176471 , ..., 0.5764706 , 0.64705884,
#         0.6       ],
#        [0.85882354, 0.7372549 , 0.73333335, ..., 0.49411765, 0.5921569 ,
#         0.6156863 ]], dtype=float32)

# %%
it=iter(trainloader)
real_batch = next(iter(it))
plt.figure(figsize=(15,15))
print(real_batch[0].size())
plt.imshow(np.transpose(utils.make_grid(real_batch[0][:64], padding=2, normalize=True).cpu(),(1,2,0)),cmap='gray')
plt.axis('off')
plt.title('Samples from the CIFAR10 Dataset');
plt.show()
# Out:
# torch.Size([128, 1, 32, 32])
