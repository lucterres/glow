# %%
import dataSeismic as ds
import numpy as np

# %%
trainset = ds.train_dataset
trainloader=ds.train_loader

# %%
import matplotlib.pyplot as plt
from torchvision import utils
i=2

tensorImg = trainset[i][0]
numpyImg = tensorImg.numpy()[0]
plt.figure(figsize=(20,20))
plt.subplot(1, 2, 1); plt.imshow(numpyImg);  plt.axis('off')
plt.title(trainset[i][1])
plt.show()

# %%
import os
import dir_local as d
from PIL import Image

# %%
img_dir = d.TRAIN_IMAGE_DIR
filename = '0d3b5ec2a8' 
filepath = filename + '.png'
img_path = os.path.join(img_dir, filepath)
image = Image.open(img_path)

image.getbbox()
# Out:
# (0, 0, 101, 101)

# %%
numpyImg.shape
numpyImg
# Out:
# array([[0.627451  , 0.67058825, 0.63529414, ..., 0.627451  , 0.5529412 ,
#         0.48235294],
#        [0.6666667 , 0.65882355, 0.5764706 , ..., 0.6431373 , 0.5647059 ,
#         0.49411765],
#        [0.67058825, 0.5882353 , 0.56078434, ..., 0.6509804 , 0.5764706 ,
#         0.5137255 ],
#        ...,
#        [0.7254902 , 0.69803923, 0.5529412 , ..., 0.61960787, 0.54509807,
#         0.5176471 ],
#        [0.7529412 , 0.6       , 0.50980395, ..., 0.60784316, 0.5372549 ,
#         0.5294118 ],
#        [0.65882355, 0.5137255 , 0.49019608, ..., 0.5882353 , 0.50980395,
#         0.48235294]], dtype=float32)

# %%
it=iter(trainloader)
real_batch = next(iter(it))
plt.figure(figsize=(15,15))
print(real_batch[0].size())
plt.imshow(np.transpose(utils.make_grid(real_batch[0][:64], padding=2, normalize=True).cpu(),(1,2,0)),cmap='gray')
plt.axis('off')
plt.title('Samples from the CIFAR10 Dataset');
plt.show()
# Out:
# torch.Size([64, 1, 32, 32])
