# %%
import dataSeismic as ds
import numpy as np

# %%
trainset = ds.train_dataset
trainloader=ds.train_loader

# %%
import matplotlib.pyplot as plt
from torchvision import utils
i=2

tensorImg = trainset[i][0]
numpyImg = tensorImg.numpy()[0]
plt.figure(figsize=(20,20))
plt.subplot(1, 2, 1); plt.imshow(numpyImg);  plt.axis('off')
plt.title(trainset[i][1])
plt.show()

# %%
import os
import directories as d
from PIL import Image

# %%
img_dir = d.TRAIN_IMAGE_DIR
filename = '0d3b5ec2a8' 
filepath = filename + '.png'
img_path = os.path.join(img_dir, filepath)
image = Image.open(img_path)

image.getbbox()
# Out:
# (0, 0, 101, 101)

# %%
numpyImg.shape
numpyImg
# Out:
# array([[0.49803922, 0.6392157 , 0.6784314 , ..., 0.69411767, 0.34117648,
#         0.47058824],
#        [0.47058824, 0.5647059 , 0.5176471 , ..., 0.7019608 , 0.25490198,
#         0.5254902 ],
#        [0.34117648, 0.41568628, 0.36862746, ..., 0.654902  , 0.27058825,
#         0.5882353 ],
#        ...,
#        [0.52156866, 0.58431375, 0.5764706 , ..., 0.4509804 , 0.4745098 ,
#         0.3764706 ],
#        [0.47843137, 0.50980395, 0.5372549 , ..., 0.44705883, 0.49411765,
#         0.34509805],
#        [0.44313726, 0.44705883, 0.5019608 , ..., 0.4117647 , 0.49803922,
#         0.40784314]], dtype=float32)

# %%
it=iter(trainloader)
real_batch = next(iter(it))
plt.figure(figsize=(15,15))
print(real_batch[0].size())
plt.imshow(np.transpose(utils.make_grid(real_batch[0][:64], padding=2, normalize=True).cpu(),(1,2,0)),cmap='gray')
plt.axis('off')
plt.title('Samples from the CIFAR10 Dataset');
plt.show()
# Out:
# torch.Size([128, 1, 32, 32])
